# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephMuschialli/QM2/blob/main/Project/Newbrazildatabyage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib
import pylab
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
from scipy.stats import norm
# %matplotlib inline
plt.style.use('ggplot')
pylab.rcParams['figure.figsize'] = (10., 8.)
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8b24583a-4b57-461f-9587-e254d44e5b6f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8b24583a-4b57-461f-9587-e254d44e5b6f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('databyage.csv')
df = df.replace('years','',regex = True)
df = df[df['metric']=='Number']
df['Dist. of Diagnoses']=df['val']/df['val'].sum()

# Manually inputting the median age of each interval. ie: 1-4 = 2, 5-9 = 7 etc...

df['average age']=[2,2,2,7,7,7,12,12,12,17,17,17,22,22,22,27,27,27,32,32,32,37,37,37,42,42,42,47,47,47,52,52,52,57,57,57,62,62,62,67,67,67,72,72,72,77,77,77,82,82,82,87,87,87,92,92,92]
df['product']=df['Dist. of Diagnoses']*df['average age']
# For 2018

df18 = df[df['year']==2018]
df18 = df18[['average age', 'Dist. of Diagnoses']]
x18 = df18['average age']
y18 = df18['Dist. of Diagnoses']
plt.scatter(x18,y18,c='green')
plt.xlabel('Age')
plt.ylabel('Distribution of Diabetes Diagnoses')
plt.title('New Type 2 Diabetes Diagnoses in Brazil in 2018 by Age')
# Out:
# Text(0.5, 1.0, 'New Type 2 Diabetes Diagnoses in Brazil in 2018 by Age')

# %%
# For 2016

df16 = df[df['year']==2016]
df16 = df16[['average age', 'Dist. of Diagnoses']]
x16 = df16['average age']
y16 = df16['Dist. of Diagnoses']
plt.scatter(x16,y16,c='red')
plt.xlabel('Age')
plt.ylabel('Distribution of Diabetes Diagnoses')
plt.title('New Type 2 Diabetes Diagnoses in Brazil in 2016 by Age')
# Out:
# Text(0.5, 1.0, 'New Type 2 Diabetes Diagnoses in Brazil in 2016 by Age')

# %%
# For 2010

df10 = df[df['year']==2010]
df10 = df10[['average age', 'Dist. of Diagnoses']]
x10 = df10['average age']
y10 = df10['Dist. of Diagnoses']
plt.scatter(x10,y10,c='blue')
plt.xlabel('Age')
plt.ylabel('Distribution of Diabetes Diagnoses')
plt.title('New Type 2 Diabetes Diagnoses in Brazil in 2010 by Age')
# Out:
# Text(0.5, 1.0, 'New Type 2 Diabetes Diagnoses in Brazil in 2010 by Age')

# %%
df
# Out:
#        measure location   sex     age       cause  metric  year           val  \
# 0    Incidence   Brazil  Both    1-4   All causes  Number  2010  1.038047e+08
# 3    Incidence   Brazil  Both    1-4   All causes  Number  2016  1.054636e+08
# 6    Incidence   Brazil  Both    1-4   All causes  Number  2018  1.046288e+08
# 9    Incidence   Brazil  Both    5-9   All causes  Number  2010  1.180595e+08
# 12   Incidence   Brazil  Both    5-9   All causes  Number  2016  1.227692e+08
# 15   Incidence   Brazil  Both    5-9   All causes  Number  2018  1.251994e+08
# 18   Incidence   Brazil  Both  10-14   All causes  Number  2010  1.092850e+08
# 21   Incidence   Brazil  Both  10-14   All causes  Number  2016  9.994590e+07
# 24   Incidence   Brazil  Both  10-14   All causes  Number  2018  1.004842e+08
# 27   Incidence   Brazil  Both  15-19   All causes  Number  2010  1.048168e+08
# 30   Incidence   Brazil  Both  15-19   All causes  Number  2016  1.023319e+08
# ...

# %%
sns.lineplot(data=df, x='average age', y='Dist. of Diagnoses', hue='year',palette='flare').set_title('Distribution of Type 2 Diabetes Diagnoses in Brazil by Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Type 2 Diabetes Diagnoses in Brazil by Age')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Product'
#
# The above exception was the direct cause of the following exception:
#
# ...
