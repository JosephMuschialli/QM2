# %% [markdown]
# <a href="https://colab.research.google.com/github/JosephMuschialli/QM2/blob/main/Project/Brazilian_States_Over_Time.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib
import pylab
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
from scipy.stats import norm
# %matplotlib inline
plt.style.use('ggplot')
pylab.rcParams['figure.figsize'] = (10., 8.)
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-96c68d1b-39d0-4dce-af62-5ca3656c7e15" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96c68d1b-39d0-4dce-af62-5ca3656c7e15">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Databylocationandtimebrazil.csv')
df = df[df['location']!='Global']
df = df[df['metric']=='Number']
df8 = df[df['year']==2018]
sns.countplot(data=df8, x = 'location')
# Out:
# <Axes: xlabel='location', ylabel='count'>

# %%
df['Number of Incidences of Type 2 Diabetes (In Millions)'] = df['val']/100000
df['Year']=df['year']
sns.lineplot(data=df, x="Year", y='Number of Incidences of Type 2 Diabetes (In Millions)', hue = 'location',size=10).set_title('Number of Incidences of Type 2 Diabetes in Brazillian States')
# Out:
# Text(0.5, 1.0, 'Number of Incidences of Type 2 Diabetes in Brazillian States')

# %%
dfh = df[df['Number of Incidences of Type 2 Diabetes (In Millions)']>=500]

# %%
sns.lineplot(data=dfh, x="Year", y='Number of Incidences of Type 2 Diabetes (In Millions)', hue = 'location').set_title('Number of Incidences of Type 2 Diabetes in Top 10 Brazillian States')
# Out:
# Text(0.5, 1.0, 'Number of Incidences of Type 2 Diabetes in Top 10 Brazillian States')
